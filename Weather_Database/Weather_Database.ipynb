# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy




# Import the datetime module from the datatime library
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
import requests
from config import weather_api_keys

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_keys
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=d2c9d2493e0412e81cec53bf032ff101

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
 # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
                          
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | uk
# City not found. Skipping...
# Processing Record 3 of Set 1 | nuuk
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | calabozo
# Processing Record 7 of Set 1 | beringovskiy
# Processing Record 8 of Set 1 | pasighat
# Processing Record 9 of Set 1 | talakan
# Processing Record 10 of Set 1 | adrar
# Processing Record 11 of Set 1 | axixa do tocantins
# City not found. Skipping...
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | tasiilaq
# Processing Record 15 of Set 1 | hami
# Processing Record 16 of Set 1 | inuvik
# Processing Record 17 of Set 1 | provideniya
# Processing Record 18 of Set 1 | humaita
# Processing Record 19 of Set 1 | garissa
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 1 | kieta
# Processing Record 24 of Set 1 | chuy
# Processing Record 25 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 1 | mar del plata
# Processing Record 27 of Set 1 | aksarka
# Processing Record 28 of Set 1 | kawerau
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | bonaventure
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | yabelo
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | basirpur
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | natal
# Processing Record 43 of Set 1 | kavieng
# Processing Record 44 of Set 1 | hofn
# Processing Record 45 of Set 1 | lufkin
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | qianan
# Processing Record 49 of Set 1 | port blair
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | tocopilla
# Processing Record 2 of Set 2 | belluno
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | souillac
# Processing Record 6 of Set 2 | dunedin
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | amahai
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | grand-lahou
# Processing Record 11 of Set 2 | igarka
# Processing Record 12 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 2 | bengkulu
# Processing Record 14 of Set 2 | kahului
# Processing Record 15 of Set 2 | aviles
# Processing Record 16 of Set 2 | rovenki
# Processing Record 17 of Set 2 | vao
# Processing Record 18 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | los llanos de aridane
# Processing Record 21 of Set 2 | atasu
# Processing Record 22 of Set 2 | ilulissat
# Processing Record 23 of Set 2 | katsuura
# Processing Record 24 of Set 2 | nanortalik
# Processing Record 25 of Set 2 | kirakira
# Processing Record 26 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 2 | askino
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | tiksi
# Processing Record 30 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 31 of Set 2 | kimbe
# Processing Record 32 of Set 2 | yatou
# Processing Record 33 of Set 2 | hambantota
# Processing Record 34 of Set 2 | upernavik
# Processing Record 35 of Set 2 | hithadhoo
# Processing Record 36 of Set 2 | krasnyy chikoy
# Processing Record 37 of Set 2 | gejiu
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | mogadishu
# Processing Record 40 of Set 2 | grindavik
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | auki
# Processing Record 43 of Set 2 | salalah
# Processing Record 44 of Set 2 | lorengau
# Processing Record 45 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 2 | taoudenni
# Processing Record 47 of Set 2 | nouadhibou
# Processing Record 48 of Set 2 | cidreira
# Processing Record 49 of Set 2 | srostki
# Processing Record 50 of Set 2 | puerto ayora
# Processing Record 1 of Set 3 | georgetown
# Processing Record 2 of Set 3 | huayang
# Processing Record 3 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | pevek
# Processing Record 5 of Set 3 | albany
# Processing Record 6 of Set 3 | norman wells
# Processing Record 7 of Set 3 | kilindoni
# Processing Record 8 of Set 3 | ahuimanu
# Processing Record 9 of Set 3 | tessalit
# Processing Record 10 of Set 3 | cabo san lucas
# Processing Record 11 of Set 3 | hilo
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | fort nelson
# Processing Record 14 of Set 3 | saint-augustin
# Processing Record 15 of Set 3 | ancud
# Processing Record 16 of Set 3 | barcelos
# Processing Record 17 of Set 3 | kodiak
# Processing Record 18 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 3 | huilong
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | athabasca
# Processing Record 23 of Set 3 | skegness
# Processing Record 24 of Set 3 | sacramento
# Processing Record 25 of Set 3 | ucluelet
# Processing Record 26 of Set 3 | mujiayingzi
# Processing Record 27 of Set 3 | longonjo
# Processing Record 28 of Set 3 | bitburg
# Processing Record 29 of Set 3 | tual
# Processing Record 30 of Set 3 | kasungu
# Processing Record 31 of Set 3 | sola
# Processing Record 32 of Set 3 | alyangula
# Processing Record 33 of Set 3 | new norfolk
# Processing Record 34 of Set 3 | george
# Processing Record 35 of Set 3 | fayaoue
# Processing Record 36 of Set 3 | pacific grove
# Processing Record 37 of Set 3 | zarinsk
# Processing Record 38 of Set 3 | uttarkashi
# Processing Record 39 of Set 3 | the valley
# Processing Record 40 of Set 3 | vyshhorod
# Processing Record 41 of Set 3 | kavaratti
# Processing Record 42 of Set 3 | svetlogorsk
# Processing Record 43 of Set 3 | jamestown
# Processing Record 44 of Set 3 | concarneau
# Processing Record 45 of Set 3 | kidal
# Processing Record 46 of Set 3 | san patricio
# Processing Record 47 of Set 3 | tukrah
# Processing Record 48 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 3 | porto novo
# Processing Record 50 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 4 | ahipara
# Processing Record 2 of Set 4 | tuatapere
# Processing Record 3 of Set 4 | boende
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | villamontes
# Processing Record 6 of Set 4 | yellowknife
# Processing Record 7 of Set 4 | busselton
# Processing Record 8 of Set 4 | pafos
# Processing Record 9 of Set 4 | luena
# Processing Record 10 of Set 4 | imbituba
# Processing Record 11 of Set 4 | santa isabel do rio negro
# Processing Record 12 of Set 4 | kodar
# Processing Record 13 of Set 4 | tazovskiy
# Processing Record 14 of Set 4 | buraydah
# Processing Record 15 of Set 4 | komagane
# Processing Record 16 of Set 4 | kaitangata
# Processing Record 17 of Set 4 | bilma
# Processing Record 18 of Set 4 | road town
# Processing Record 19 of Set 4 | villa bisono
# Processing Record 20 of Set 4 | noumea
# Processing Record 21 of Set 4 | ereymentau
# Processing Record 22 of Set 4 | isangel
# Processing Record 23 of Set 4 | itoman
# Processing Record 24 of Set 4 | jibuti
# Processing Record 25 of Set 4 | laguna
# Processing Record 26 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 4 | rabaul
# Processing Record 28 of Set 4 | tanda
# Processing Record 29 of Set 4 | saint george
# Processing Record 30 of Set 4 | klaksvik
# Processing Record 31 of Set 4 | banda aceh
# Processing Record 32 of Set 4 | lagoa
# Processing Record 33 of Set 4 | carnarvon
# Processing Record 34 of Set 4 | chokurdakh
# Processing Record 35 of Set 4 | torquay
# Processing Record 36 of Set 4 | mahebourg
# Processing Record 37 of Set 4 | vila
# Processing Record 38 of Set 4 | esso
# Processing Record 39 of Set 4 | poum
# Processing Record 40 of Set 4 | chara
# Processing Record 41 of Set 4 | srednekolymsk
# Processing Record 42 of Set 4 | viedma
# Processing Record 43 of Set 4 | kruisfontein
# Processing Record 44 of Set 4 | cockburn town
# Processing Record 45 of Set 4 | brockville
# Processing Record 46 of Set 4 | dingle
# Processing Record 47 of Set 4 | prieska
# Processing Record 48 of Set 4 | sitka
# Processing Record 49 of Set 4 | plettenberg bay
# Processing Record 50 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 1 of Set 5 | meulaboh
# Processing Record 2 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 3 of Set 5 | sao filipe
# Processing Record 4 of Set 5 | fallon
# Processing Record 5 of Set 5 | whittlesea
# Processing Record 6 of Set 5 | homestead
# Processing Record 7 of Set 5 | bacolod
# Processing Record 8 of Set 5 | victoria
# Processing Record 9 of Set 5 | comodoro rivadavia
# Processing Record 10 of Set 5 | ola
# Processing Record 11 of Set 5 | karratha
# Processing Record 12 of Set 5 | stalowa wola
# Processing Record 13 of Set 5 | atascadero
# Processing Record 14 of Set 5 | dikson
# Processing Record 15 of Set 5 | ponta delgada
# Processing Record 16 of Set 5 | airai
# Processing Record 17 of Set 5 | north bend
# Processing Record 18 of Set 5 | honiara
# Processing Record 19 of Set 5 | iqaluit
# Processing Record 20 of Set 5 | leningradskiy
# Processing Record 21 of Set 5 | mount gambier
# Processing Record 22 of Set 5 | powell river
# Processing Record 23 of Set 5 | yulara
# Processing Record 24 of Set 5 | bairiki
# Processing Record 25 of Set 5 | maykor
# Processing Record 26 of Set 5 | lompoc
# Processing Record 27 of Set 5 | rio gallegos
# Processing Record 28 of Set 5 | luderitz
# Processing Record 29 of Set 5 | manavalakurichi
# Processing Record 30 of Set 5 | codrington
# Processing Record 31 of Set 5 | nokaneng
# Processing Record 32 of Set 5 | rivadavia
# Processing Record 33 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 34 of Set 5 | arzgir
# Processing Record 35 of Set 5 | vega de alatorre
# Processing Record 36 of Set 5 | eskil
# Processing Record 37 of Set 5 | sakakah
# Processing Record 38 of Set 5 | kennett
# Processing Record 39 of Set 5 | sicamous
# Processing Record 40 of Set 5 | itarema
# Processing Record 41 of Set 5 | taltal
# Processing Record 42 of Set 5 | bonavista
# Processing Record 43 of Set 5 | zhigansk
# Processing Record 44 of Set 5 | saint-pierre
# Processing Record 45 of Set 5 | touros
# Processing Record 46 of Set 5 | severo-kurilsk
# Processing Record 47 of Set 5 | esperance
# Processing Record 48 of Set 5 | clyde river
# Processing Record 49 of Set 5 | tanabe
# Processing Record 50 of Set 5 | elk point
# Processing Record 1 of Set 6 | odweyne
# Processing Record 2 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 3 of Set 6 | ponta do sol
# Processing Record 4 of Set 6 | half moon bay
# Processing Record 5 of Set 6 | lamar
# Processing Record 6 of Set 6 | kamenskiy
# Processing Record 7 of Set 6 | tuktoyaktuk
# Processing Record 8 of Set 6 | ellisras
# Processing Record 9 of Set 6 | smithers
# Processing Record 10 of Set 6 | muisne
# Processing Record 11 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 12 of Set 6 | pisco
# Processing Record 13 of Set 6 | cuamba
# Processing Record 14 of Set 6 | cabra
# Processing Record 15 of Set 6 | flinders
# Processing Record 16 of Set 6 | geraldton
# Processing Record 17 of Set 6 | mehamn
# Processing Record 18 of Set 6 | kyra
# Processing Record 19 of Set 6 | puerto baquerizo moreno
# Processing Record 20 of Set 6 | abu dhabi
# Processing Record 21 of Set 6 | ndende
# Processing Record 22 of Set 6 | yar-sale
# Processing Record 23 of Set 6 | celendin
# Processing Record 24 of Set 6 | jining
# Processing Record 25 of Set 6 | punta cardon
# Processing Record 26 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 6 | healdsburg
# Processing Record 28 of Set 6 | sindand
# City not found. Skipping...
# Processing Record 29 of Set 6 | saldanha
# Processing Record 30 of Set 6 | alice springs
# Processing Record 31 of Set 6 | divnogorsk
# Processing Record 32 of Set 6 | gamba
# Processing Record 33 of Set 6 | teya
# Processing Record 34 of Set 6 | nouakchott
# Processing Record 35 of Set 6 | ribeira grande
# Processing Record 36 of Set 6 | faanui
# Processing Record 37 of Set 6 | constitucion
# Processing Record 38 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 6 | vanderhoof
# Processing Record 40 of Set 6 | susaki
# Processing Record 41 of Set 6 | erenhot
# Processing Record 42 of Set 6 | lipin bor
# Processing Record 43 of Set 6 | belyy yar
# Processing Record 44 of Set 6 | velizh
# Processing Record 45 of Set 6 | olafsvik
# Processing Record 46 of Set 6 | khor
# Processing Record 47 of Set 6 | taboga
# Processing Record 48 of Set 6 | santa ana
# Processing Record 49 of Set 6 | coihaique
# Processing Record 50 of Set 6 | tambul
# City not found. Skipping...
# Processing Record 1 of Set 7 | sucre
# Processing Record 2 of Set 7 | junction city
# Processing Record 3 of Set 7 | roebourne
# Processing Record 4 of Set 7 | malchin
# Processing Record 5 of Set 7 | rogers
# Processing Record 6 of Set 7 | bethel
# Processing Record 7 of Set 7 | gunjur
# Processing Record 8 of Set 7 | portmarnock
# Processing Record 9 of Set 7 | hasaki
# Processing Record 10 of Set 7 | berlevag
# Processing Record 11 of Set 7 | vila do maio
# Processing Record 12 of Set 7 | longyearbyen
# Processing Record 13 of Set 7 | staryy nadym
# Processing Record 14 of Set 7 | bambous virieux
# Processing Record 15 of Set 7 | peniche
# Processing Record 16 of Set 7 | koslan
# Processing Record 17 of Set 7 | hauterive
# Processing Record 18 of Set 7 | brownsville
# Processing Record 19 of Set 7 | el congo
# Processing Record 20 of Set 7 | alofi
# Processing Record 21 of Set 7 | prince rupert
# Processing Record 22 of Set 7 | biak
# Processing Record 23 of Set 7 | brae
# Processing Record 24 of Set 7 | reconquista
# Processing Record 25 of Set 7 | port macquarie
# Processing Record 26 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 7 | cherskiy
# Processing Record 28 of Set 7 | nabire
# Processing Record 29 of Set 7 | washington
# Processing Record 30 of Set 7 | yabrud
# Processing Record 31 of Set 7 | puri
# Processing Record 32 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 7 | luanda
# Processing Record 34 of Set 7 | kupang
# Processing Record 35 of Set 7 | tarnogskiy gorodok
# Processing Record 36 of Set 7 | tambun
# Processing Record 37 of Set 7 | samarai
# Processing Record 38 of Set 7 | kabale
# Processing Record 39 of Set 7 | panama city
# Processing Record 40 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 7 | golden
# Processing Record 42 of Set 7 | nantucket
# Processing Record 43 of Set 7 | tolaga bay
# Processing Record 44 of Set 7 | saint anthony
# Processing Record 45 of Set 7 | yarkovo
# Processing Record 46 of Set 7 | balikpapan
# Processing Record 47 of Set 7 | maceio
# Processing Record 48 of Set 7 | kushima
# Processing Record 49 of Set 7 | paamiut
# Processing Record 50 of Set 7 | solok
# Processing Record 1 of Set 8 | nhlangano
# Processing Record 2 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 8 | vila velha
# Processing Record 4 of Set 8 | sampit
# Processing Record 5 of Set 8 | la ronge
# Processing Record 6 of Set 8 | veraval
# Processing Record 7 of Set 8 | aklavik
# Processing Record 8 of Set 8 | trincomalee
# Processing Record 9 of Set 8 | vucje
# Processing Record 10 of Set 8 | inhambane
# Processing Record 11 of Set 8 | bima
# Processing Record 12 of Set 8 | aguadilla
# Processing Record 13 of Set 8 | kainantu
# Processing Record 14 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 15 of Set 8 | coxim
# Processing Record 16 of Set 8 | batemans bay
# Processing Record 17 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 8 | emba
# Processing Record 19 of Set 8 | hay river
# Processing Record 20 of Set 8 | waitara
# Processing Record 21 of Set 8 | port-gentil
# Processing Record 22 of Set 8 | benguela
# Processing Record 23 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 8 | dalvik
# Processing Record 25 of Set 8 | trapani
# Processing Record 26 of Set 8 | aykhal
# Processing Record 27 of Set 8 | anadyr
# Processing Record 28 of Set 8 | pangnirtung
# Processing Record 29 of Set 8 | bryan
# Processing Record 30 of Set 8 | vardo
# Processing Record 31 of Set 8 | iskateley
# Processing Record 32 of Set 8 | shitanjing
# Processing Record 33 of Set 8 | guerrero negro
# Processing Record 34 of Set 8 | manokwari
# Processing Record 35 of Set 8 | takoradi
# Processing Record 36 of Set 8 | palaia fokaia
# Processing Record 37 of Set 8 | aktash
# Processing Record 38 of Set 8 | namibe
# Processing Record 39 of Set 8 | caravelas
# Processing Record 40 of Set 8 | mount isa
# Processing Record 41 of Set 8 | victor harbor
# Processing Record 42 of Set 8 | mayumba
# Processing Record 43 of Set 8 | talnakh
# Processing Record 44 of Set 8 | aksu
# Processing Record 45 of Set 8 | sorong
# Processing Record 46 of Set 8 | sur
# Processing Record 47 of Set 8 | kamenka
# Processing Record 48 of Set 8 | ambilobe
# Processing Record 49 of Set 8 | nemuro
# Processing Record 50 of Set 8 | santa fe
# Processing Record 1 of Set 9 | port hardy
# Processing Record 2 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 9 | sorland
# Processing Record 4 of Set 9 | praia da vitoria
# Processing Record 5 of Set 9 | pinawa
# Processing Record 6 of Set 9 | kalmunai
# Processing Record 7 of Set 9 | valdemarpils
# Processing Record 8 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 9 | cap malheureux
# Processing Record 10 of Set 9 | maloy
# Processing Record 11 of Set 9 | kindu
# Processing Record 12 of Set 9 | nabul
# City not found. Skipping...
# Processing Record 13 of Set 9 | goderich
# Processing Record 14 of Set 9 | la palma
# Processing Record 15 of Set 9 | norfolk
# Processing Record 16 of Set 9 | russell
# Processing Record 17 of Set 9 | altay
# Processing Record 18 of Set 9 | visaginas
# Processing Record 19 of Set 9 | stephenville
# Processing Record 20 of Set 9 | huinan
# Processing Record 21 of Set 9 | nalut
# Processing Record 22 of Set 9 | andenes
# Processing Record 23 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 9 | college
# Processing Record 25 of Set 9 | villeneuve-sur-lot
# Processing Record 26 of Set 9 | dukat
# Processing Record 27 of Set 9 | koboko
# Processing Record 28 of Set 9 | artyom
# Processing Record 29 of Set 9 | kerouane
# Processing Record 30 of Set 9 | neiafu
# Processing Record 31 of Set 9 | leh
# Processing Record 32 of Set 9 | cartagena
# Processing Record 33 of Set 9 | grand gaube
# Processing Record 34 of Set 9 | shelburne
# Processing Record 35 of Set 9 | vila franca do campo
# Processing Record 36 of Set 9 | murgab
# Processing Record 37 of Set 9 | diffa
# Processing Record 38 of Set 9 | rochester
# Processing Record 39 of Set 9 | amol
# Processing Record 40 of Set 9 | narsaq
# Processing Record 41 of Set 9 | jizan
# Processing Record 42 of Set 9 | cayenne
# Processing Record 43 of Set 9 | dhidhdhoo
# Processing Record 44 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 9 | choucheng
# City not found. Skipping...
# Processing Record 46 of Set 9 | quatre cocos
# Processing Record 47 of Set 9 | southbridge
# Processing Record 48 of Set 9 | bronnoysund
# Processing Record 49 of Set 9 | maarianhamina
# Processing Record 50 of Set 9 | saurimo
# Processing Record 1 of Set 10 | chapais
# Processing Record 2 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 3 of Set 10 | kroya
# Processing Record 4 of Set 10 | parakou
# Processing Record 5 of Set 10 | kailua
# Processing Record 6 of Set 10 | camacha
# Processing Record 7 of Set 10 | alamosa
# Processing Record 8 of Set 10 | magadan
# Processing Record 9 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 10 | revelstoke
# Processing Record 11 of Set 10 | lavrentiya
# Processing Record 12 of Set 10 | havre-saint-pierre
# Processing Record 13 of Set 10 | hervey bay
# Processing Record 14 of Set 10 | fort wellington
# Processing Record 15 of Set 10 | shakawe
# Processing Record 16 of Set 10 | ipanema
# Processing Record 17 of Set 10 | guerande
# Processing Record 18 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 10 | puerto lumbreras
# Processing Record 20 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 21 of Set 10 | west bay
# Processing Record 22 of Set 10 | moanda
# Processing Record 23 of Set 10 | dabhol
# Processing Record 24 of Set 10 | mae sai
# Processing Record 25 of Set 10 | baghdad
# Processing Record 26 of Set 10 | marang
# Processing Record 27 of Set 10 | porto seguro
# Processing Record 28 of Set 10 | riyadh
# Processing Record 29 of Set 10 | umm kaddadah
# Processing Record 30 of Set 10 | cabinda
# Processing Record 31 of Set 10 | trossingen
# Processing Record 32 of Set 10 | terrace
# Processing Record 33 of Set 10 | henties bay
# Processing Record 34 of Set 10 | jelling
# Processing Record 35 of Set 10 | burica
# City not found. Skipping...
# Processing Record 36 of Set 10 | lasa
# Processing Record 37 of Set 10 | meadow lake
# Processing Record 38 of Set 10 | plerin
# Processing Record 39 of Set 10 | harper
# Processing Record 40 of Set 10 | canico
# Processing Record 41 of Set 10 | port moresby
# Processing Record 42 of Set 10 | san rafael
# Processing Record 43 of Set 10 | sovetskiy
# Processing Record 44 of Set 10 | vaitape
# Processing Record 45 of Set 10 | lilongwe
# Processing Record 46 of Set 10 | mazagao
# Processing Record 47 of Set 10 | lazaro cardenas
# Processing Record 48 of Set 10 | kolokani
# Processing Record 49 of Set 10 | severomuysk
# Processing Record 50 of Set 10 | platanos
# Processing Record 1 of Set 11 | aquiles serdan
# Processing Record 2 of Set 11 | omboue
# Processing Record 3 of Set 11 | rocky mountain house
# Processing Record 4 of Set 11 | necochea
# Processing Record 5 of Set 11 | shubarkuduk
# Processing Record 6 of Set 11 | moshi
# Processing Record 7 of Set 11 | bati
# Processing Record 8 of Set 11 | margate
# Processing Record 9 of Set 11 | inta
# Processing Record 10 of Set 11 | zhuanghe
# Processing Record 11 of Set 11 | kuhdasht
# Processing Record 12 of Set 11 | japura
# Processing Record 13 of Set 11 | richards bay
# Processing Record 14 of Set 11 | tacuarembo
# Processing Record 15 of Set 11 | arlit
# Processing Record 16 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 17 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 18 of Set 11 | paraguacu paulista
# Processing Record 19 of Set 11 | giddalur
# Processing Record 20 of Set 11 | port lincoln
# Processing Record 21 of Set 11 | boa vista
# Processing Record 22 of Set 11 | oksfjord
# Processing Record 23 of Set 11 | minuri
# Processing Record 24 of Set 11 | mareeba
# Processing Record 25 of Set 11 | kargasok
# Processing Record 26 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 11 | kayerkan
# Processing Record 28 of Set 11 | rawson
# Processing Record 29 of Set 11 | bereda
# Processing Record 30 of Set 11 | isiro
# Processing Record 31 of Set 11 | panaba
# Processing Record 32 of Set 11 | digha
# Processing Record 33 of Set 11 | colesberg
# Processing Record 34 of Set 11 | acarau
# Processing Record 35 of Set 11 | mokhsogollokh
# Processing Record 36 of Set 11 | hualmay
# Processing Record 37 of Set 11 | champerico
# Processing Record 38 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 11 | vanimo
# Processing Record 41 of Set 11 | requena
# Processing Record 42 of Set 11 | niquinohomo
# Processing Record 43 of Set 11 | mandalgovi
# Processing Record 44 of Set 11 | east wenatchee bench
# Processing Record 45 of Set 11 | asau
# Processing Record 46 of Set 11 | la maddalena
# Processing Record 47 of Set 11 | cururupu
# Processing Record 48 of Set 11 | coquimbo
# Processing Record 49 of Set 11 | shingu
# Processing Record 50 of Set 11 | bilibino
# Processing Record 1 of Set 12 | san luis
# Processing Record 2 of Set 12 | kudahuvadhoo
# Processing Record 3 of Set 12 | grieskirchen
# Processing Record 4 of Set 12 | santiago del estero
# Processing Record 5 of Set 12 | ostrovnoy
# Processing Record 6 of Set 12 | bandarbeyla
# Processing Record 7 of Set 12 | atambua
# Processing Record 8 of Set 12 | chanhassen
# Processing Record 9 of Set 12 | tres passos
# Processing Record 10 of Set 12 | kiunga
# Processing Record 11 of Set 12 | coahuayana
# Processing Record 12 of Set 12 | isiolo
# Processing Record 13 of Set 12 | corowa
# Processing Record 14 of Set 12 | katobu
# Processing Record 15 of Set 12 | bindura
# Processing Record 16 of Set 12 | isla aguada
# Processing Record 17 of Set 12 | yaan
# Processing Record 18 of Set 12 | kapiri mposhi
# Processing Record 19 of Set 12 | talara
# Processing Record 20 of Set 12 | huai yot
# Processing Record 21 of Set 12 | sao felix do xingu
# Processing Record 22 of Set 12 | karakol
# Processing Record 23 of Set 12 | jiangdu
# Processing Record 24 of Set 12 | ngunguru
# Processing Record 25 of Set 12 | isla mujeres
# Processing Record 26 of Set 12 | vershino-darasunskiy
# Processing Record 27 of Set 12 | bathsheba
# Processing Record 28 of Set 12 | mugreyevskiy
# City not found. Skipping...
# Processing Record 29 of Set 12 | betioky
# Processing Record 30 of Set 12 | san jose
# Processing Record 31 of Set 12 | sapouy
# Processing Record 32 of Set 12 | koumac
# Processing Record 33 of Set 12 | surt
# Processing Record 34 of Set 12 | kaeo
# Processing Record 35 of Set 12 | inirida
# Processing Record 36 of Set 12 | tabuk
# Processing Record 37 of Set 12 | iracoubo
# Processing Record 38 of Set 12 | faya
# Processing Record 39 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 12 | cervignano del friuli
# Processing Record 41 of Set 12 | matamoros
# Processing Record 42 of Set 12 | kismayo
# Processing Record 43 of Set 12 | bambanglipuro
# Processing Record 44 of Set 12 | paciran
# Processing Record 45 of Set 12 | naryan-mar
# Processing Record 46 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 47 of Set 12 | vostok
# Processing Record 48 of Set 12 | praia
# Processing Record 49 of Set 12 | pangody
# Processing Record 50 of Set 12 | korla
# Processing Record 1 of Set 13 | kozhva
# Processing Record 2 of Set 13 | kuva
# City not found. Skipping...
# Processing Record 3 of Set 13 | derbent
# Processing Record 4 of Set 13 | hai phong
# City not found. Skipping...
# Processing Record 5 of Set 13 | klasterec nad ohri
# Processing Record 6 of Set 13 | mbini
# Processing Record 7 of Set 13 | pointe michel
# Processing Record 8 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 9 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 10 of Set 13 | kanigoro
# Processing Record 11 of Set 13 | saint-georges
# Processing Record 12 of Set 13 | marawi
# Processing Record 13 of Set 13 | wewak
# Processing Record 14 of Set 13 | mishkino
# Processing Record 15 of Set 13 | dongsheng
# Processing Record 16 of Set 13 | vestmannaeyjar
# Processing Record 17 of Set 13 | naze
# Processing Record 18 of Set 13 | tiarei
# Processing Record 19 of Set 13 | puerto colombia
# Processing Record 20 of Set 13 | laurel
# Processing Record 21 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 13 | mayo
# Processing Record 23 of Set 13 | kasongo-lunda
# Processing Record 24 of Set 13 | dumai
# Processing Record 25 of Set 13 | fare
# Processing Record 26 of Set 13 | borogontsy
# Processing Record 27 of Set 13 | gao
# Processing Record 28 of Set 13 | sept-iles
# Processing Record 29 of Set 13 | gravdal
# Processing Record 30 of Set 13 | namie
# Processing Record 31 of Set 13 | tairua
# Processing Record 32 of Set 13 | bukama
# Processing Record 33 of Set 13 | karatsu
# Processing Record 34 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 35 of Set 13 | yima
# Processing Record 36 of Set 13 | puerto quijarro
# Processing Record 37 of Set 13 | husavik
# Processing Record 38 of Set 13 | namatanai
# Processing Record 39 of Set 13 | zholymbet
# Processing Record 40 of Set 13 | pitimbu
# Processing Record 41 of Set 13 | sibolga
# Processing Record 42 of Set 13 | bulembu
# Processing Record 43 of Set 13 | yurty
# Processing Record 44 of Set 13 | guymon
# Processing Record 45 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 46 of Set 13 | ndele
# Processing Record 47 of Set 13 | chicama
# Processing Record 48 of Set 13 | san vicente
# Processing Record 49 of Set 13 | broken hill
# Processing Record 50 of Set 13 | hamilton
# Processing Record 1 of Set 14 | granada
# Processing Record 2 of Set 14 | araouane
# Processing Record 3 of Set 14 | cabedelo
# Processing Record 4 of Set 14 | puerto el triunfo
# Processing Record 5 of Set 14 | capim grosso
# Processing Record 6 of Set 14 | bonthe
# Processing Record 7 of Set 14 | tooele
# Processing Record 8 of Set 14 | baiyin
# Processing Record 9 of Set 14 | basco
# Processing Record 10 of Set 14 | san ramon
# Processing Record 11 of Set 14 | luwuk
# Processing Record 12 of Set 14 | ketchikan
# Processing Record 13 of Set 14 | pomabamba
# Processing Record 14 of Set 14 | tommot
# Processing Record 15 of Set 14 | teguldet
# Processing Record 16 of Set 14 | makakilo city
# Processing Record 17 of Set 14 | hecun
# Processing Record 18 of Set 14 | newport
# Processing Record 19 of Set 14 | bitung
# Processing Record 20 of Set 14 | sao miguel do araguaia
# Processing Record 21 of Set 14 | kristiinankaupunki
# Processing Record 22 of Set 14 | evensk
# Processing Record 23 of Set 14 | fougamou
# Processing Record 24 of Set 14 | along
# Processing Record 25 of Set 14 | saint-joseph
# Processing Record 26 of Set 14 | batagay-alyta
# Processing Record 27 of Set 14 | mbandaka
# Processing Record 28 of Set 14 | parbatipur
# Processing Record 29 of Set 14 | santander
# Processing Record 30 of Set 14 | juneau
# Processing Record 31 of Set 14 | eenhana
# Processing Record 32 of Set 14 | cabatuan
# Processing Record 33 of Set 14 | shimoda
# Processing Record 34 of Set 14 | inverell
# Processing Record 35 of Set 14 | kapit
# Processing Record 36 of Set 14 | bogotol
# Processing Record 37 of Set 14 | varhaug
# Processing Record 38 of Set 14 | zhezkazgan
# Processing Record 39 of Set 14 | kathu
# Processing Record 40 of Set 14 | kita
# Processing Record 41 of Set 14 | tateyama
# Processing Record 42 of Set 14 | comrat
# Processing Record 43 of Set 14 | wucheng
# Processing Record 44 of Set 14 | maumere
# Processing Record 45 of Set 14 | dali
# Processing Record 46 of Set 14 | novobelokatay
# Processing Record 47 of Set 14 | lakes entrance
# Processing Record 48 of Set 14 | gorodishche
# Processing Record 49 of Set 14 | filadelfia
# Processing Record 50 of Set 14 | gubkinskiy
# Processing Record 1 of Set 15 | vanavara
# Processing Record 2 of Set 15 | virginia beach
# Processing Record 3 of Set 15 | halifax
# Processing Record 4 of Set 15 | lata
# Processing Record 5 of Set 15 | thinadhoo
# Processing Record 6 of Set 15 | tezu
# Processing Record 7 of Set 15 | porto empedocle
# Processing Record 8 of Set 15 | dhuburi
# Processing Record 9 of Set 15 | marion
# Processing Record 10 of Set 15 | yarmouth
# Processing Record 11 of Set 15 | capoterra
# Processing Record 12 of Set 15 | san cristobal
# Processing Record 13 of Set 15 | mitsamiouli
# Processing Record 14 of Set 15 | mangrol
# Processing Record 15 of Set 15 | kimberley
# Processing Record 16 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 17 of Set 15 | gidole
# Processing Record 18 of Set 15 | eydhafushi
# Processing Record 19 of Set 15 | xiuyan
# Processing Record 20 of Set 15 | haines junction
# Processing Record 21 of Set 15 | sardinata
# Processing Record 22 of Set 15 | feltre
# Processing Record 23 of Set 15 | san borja
# Processing Record 24 of Set 15 | dunda
# Processing Record 25 of Set 15 | fort saint james
# Processing Record 26 of Set 15 | sakaiminato
# Processing Record 27 of Set 15 | khani
# Processing Record 28 of Set 15 | severnoye
# Processing Record 29 of Set 15 | komsomolskiy
# Processing Record 30 of Set 15 | campos
# Processing Record 31 of Set 15 | la union
# Processing Record 32 of Set 15 | narasannapeta
# Processing Record 33 of Set 15 | pokoynoye
# Processing Record 34 of Set 15 | entebbe
# Processing Record 35 of Set 15 | grants pass
# Processing Record 36 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 37 of Set 15 | raudeberg
# Processing Record 38 of Set 15 | mana
# Processing Record 39 of Set 15 | pedernales
# Processing Record 40 of Set 15 | alexandria
# Processing Record 41 of Set 15 | arona
# Processing Record 42 of Set 15 | marystown
# Processing Record 43 of Set 15 | koygorodok
# Processing Record 44 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 15 | banamba
# Processing Record 46 of Set 15 | banjarmasin
# Processing Record 47 of Set 15 | hovd
# Processing Record 48 of Set 15 | burkhala
# City not found. Skipping...
# Processing Record 49 of Set 15 | hidalgotitlan
# Processing Record 50 of Set 15 | mecca
# Processing Record 1 of Set 16 | xocali
# Processing Record 2 of Set 16 | moerai
# Processing Record 3 of Set 16 | okhotsk
# Processing Record 4 of Set 16 | svetlyy
# Processing Record 5 of Set 16 | port said
# Processing Record 6 of Set 16 | owando
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -86.4384, 'lat': 11.8485},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 76.17,
#   'feels_like': 77.29,
#   'temp_min': 76.17,
#   'temp_max': 76.17,
#   'pressure': 1013,
#   'humidity': 81,
#   'sea_level': 1013,
#   'grnd_level': 998},
#  'visibility': 10000,
#  'wind': {'speed': 8.52, 'deg': 62, 'gust': 24.25},
#  'clouds': {'all': 51},
#  'dt': 1632746121,
#  'sys': {'type': 1,
#   'id': 7192,
#   'country': 'NI',
#   'sunrise': 1632742483,
#   'sunset': 1632785909},
#  'timezone': -21600,
#  'id': 3616594,
#  'name': 'San Rafael del Sur',
#  'cod': 200}

# %%
city_weather["weather"]
# Out:
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]

# %%
city_data
# Out:
# [{'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 60.96,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'TO',
#   'Current Description': 'few clouds'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 38.82,
#   'Humidity': 85,
#   'Cloudiness': 94,
#   'Wind Speed': 5.48,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 64.11,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 49.71,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 2.75,
#   'Country': 'AU',
#   'Current Description': 'few clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 75.52,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Current Description': 'moderate rain'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 76.8,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 2.98,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kodinsk',
#   'Lat': 58.6881,
#   'Lng': 99.1844,
#   'Max Temp': 34.5,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.91,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 33.93,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 12.12,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 56.05,
#   'Humidity': 90,
#   'Cloudiness': 6,
#   'Wind Speed': 9.84,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 84.88,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 1.01,
#   'Country': 'MY',
#   'Current Description': 'light rain'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 39.81,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'CL',
#   'Current Description': 'light rain'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 77.11,
#   'Humidity': 71,
#   'Cloudiness': 5,
#   'Wind Speed': 17.29,
#   'Country': 'MU',
#   'Current Description': 'clear sky'},
#  {'City': 'Yeppoon',
#   'Lat': -23.1333,
#   'Lng': 150.7333,
#   'Max Temp': 65.98,
#   'Humidity': 81,
#   'Cloudiness': 52,
#   'Wind Speed': 17.58,
#   'Country': 'AU',
#   'Current Description': 'light rain'},
#  {'City': 'Najran',
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Max Temp': 93.85,
#   'Humidity': 10,
#   'Cloudiness': 8,
#   'Wind Speed': 11.99,
#   'Country': 'SA',
#   'Current Description': 'clear sky'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 79.41,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'BB',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 52.09,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'AR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Genhe',
#   'Lat': 50.7833,
#   'Lng': 121.5167,
#   'Max Temp': 38.98,
#   'Humidity': 84,
#   'Cloudiness': 13,
#   'Wind Speed': 4.43,
#   'Country': 'CN',
#   'Current Description': 'few clouds'},
#  {'City': 'Kjollefjord',
#   'Lat': 70.9457,
#   'Lng': 27.3465,
#   'Max Temp': 57.02,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'NO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 72.54,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 50.92,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 11.01,
#   'Country': 'FO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 72.1,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 34.52,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 73.4,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 20.45,
#   'Country': 'PF',
#   'Current Description': 'clear sky'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 57.2,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'NO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Praia',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 88.34,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'CV',
#   'Current Description': 'few clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 42.91,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 71.76,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 15.21,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': 33.76,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 37.56,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 40.93,
#   'Humidity': 80,
#   'Cloudiness': 8,
#   'Wind Speed': 5.75,
#   'Country': 'NZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 67.46,
#   'Humidity': 70,
#   'Cloudiness': 2,
#   'Wind Speed': 9.17,
#   'Country': 'NC',
#   'Current Description': 'clear sky'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 69.69,
#   'Humidity': 73,
#   'Cloudiness': 27,
#   'Wind Speed': 30.29,
#   'Country': 'ZA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 49.05,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Tual',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 80.87,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 15.37,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 81.16,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 7.56,
#   'Country': 'CV',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 68.77,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 7.87,
#   'Country': 'EC',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 75.27,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Harnosand',
#   'Lat': 62.6323,
#   'Lng': 17.9379,
#   'Max Temp': 60.82,
#   'Humidity': 77,
#   'Cloudiness': 25,
#   'Wind Speed': 13.2,
#   'Country': 'SE',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 82.62,
#   'Humidity': 74,
#   'Cloudiness': 42,
#   'Wind Speed': 8.01,
#   'Country': 'PG',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 27.3,
#   'Humidity': 85,
#   'Cloudiness': 91,
#   'Wind Speed': 13.4,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 23.31,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 6.96,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Darhan',
#   'Lat': 49.4867,
#   'Lng': 105.9228,
#   'Max Temp': 39.65,
#   'Humidity': 78,
#   'Cloudiness': 9,
#   'Wind Speed': 4.36,
#   'Country': 'MN',
#   'Current Description': 'clear sky'},
#  {'City': 'Chicama',
#   'Lat': -7.8447,
#   'Lng': -79.1469,
#   'Max Temp': 57.74,
#   'Humidity': 79,
#   'Cloudiness': 48,
#   'Wind Speed': 4.94,
#   'Country': 'PE',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 81.97,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 19.55,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 28.42,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Urengoy',
#   'Lat': 65.9667,
#   'Lng': 78.3667,
#   'Max Temp': 36.37,
#   'Humidity': 78,
#   'Cloudiness': 18,
#   'Wind Speed': 6.89,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Anchorage',
#   'Lat': 61.2181,
#   'Lng': -149.9003,
#   'Max Temp': 36.28,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Viedma',
#   'Lat': -40.8135,
#   'Lng': -62.9967,
#   'Max Temp': 55.09,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 14.47,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.56,
#   'Humidity': 72,
#   'Cloudiness': 65,
#   'Wind Speed': 20.18,
#   'Country': 'PF',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 69.89,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 25.5,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Allapalli',
#   'Lat': 19.4167,
#   'Lng': 80.0667,
#   'Max Temp': 74.41,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 11.32,
#   'Country': 'IN',
#   'Current Description': 'light rain'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 28.62,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 5.35,
#   'Country': 'GL',
#   'Current Description': 'clear sky'},
#  {'City': 'Kalmar',
#   'Lat': 56.6616,
#   'Lng': 16.3616,
#   'Max Temp': 62.15,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'SE',
#   'Current Description': 'clear sky'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 33.64,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'SJ',
#   'Current Description': 'light intensity shower rain'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 62.91,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 10.07,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 61.29,
#   'Humidity': 97,
#   'Cloudiness': 90,
#   'Wind Speed': 24.16,
#   'Country': 'CA',
#   'Current Description': 'moderate rain'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 38.48,
#   'Humidity': 91,
#   'Cloudiness': 16,
#   'Wind Speed': 2.86,
#   'Country': 'NZ',
#   'Current Description': 'few clouds'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 58.28,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Daru',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp': 77.81,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 13.82,
#   'Country': 'PG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Katsina',
#   'Lat': 12.9894,
#   'Lng': 7.6006,
#   'Max Temp': 94.8,
#   'Humidity': 20,
#   'Cloudiness': 6,
#   'Wind Speed': 3.76,
#   'Country': 'NG',
#   'Current Description': 'clear sky'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 71.65,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'CK',
#   'Current Description': 'broken clouds'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 59.27,
#   'Humidity': 83,
#   'Cloudiness': 97,
#   'Wind Speed': 3.24,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Plouzane',
#   'Lat': 48.3833,
#   'Lng': -4.6167,
#   'Max Temp': 64.49,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Country': 'FR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Augusta',
#   'Lat': -32.5,
#   'Lng': 137.7667,
#   'Max Temp': 69.94,
#   'Humidity': 24,
#   'Cloudiness': 68,
#   'Wind Speed': 11.95,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 77.58,
#   'Humidity': 77,
#   'Cloudiness': 41,
#   'Wind Speed': 13.04,
#   'Country': 'JP',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 80.51,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Hanzhong',
#   'Lat': 33.0728,
#   'Lng': 107.0303,
#   'Max Temp': 64.31,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.36,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 62.92,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 77.25,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'MU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 25.11,
#   'Humidity': 60,
#   'Cloudiness': 10,
#   'Wind Speed': 4.68,
#   'Country': 'GL',
#   'Current Description': 'clear sky'},
#  {'City': 'Sistranda',
#   'Lat': 63.7256,
#   'Lng': 8.834,
#   'Max Temp': 64.9,
#   'Humidity': 74,
#   'Cloudiness': 99,
#   'Wind Speed': 7.74,
#   'Country': 'NO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pemberton',
#   'Lat': 50.3164,
#   'Lng': -122.8027,
#   'Max Temp': 53.46,
#   'Humidity': 95,
#   'Cloudiness': 24,
#   'Wind Speed': 7.38,
#   'Country': 'CA',
#   'Current Description': 'few clouds'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 78.64,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 47.07,
#   'Humidity': 90,
#   'Cloudiness': 15,
#   'Wind Speed': 9.1,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Dunedin',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 42.8,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 5.26,
#   'Country': 'NZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 55.24,
#   'Humidity': 80,
#   'Cloudiness': 96,
#   'Wind Speed': 21,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 27.32,
#   'Humidity': 88,
#   'Cloudiness': 17,
#   'Wind Speed': 6.53,
#   'Country': 'CA',
#   'Current Description': 'few clouds'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 86.22,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'HK',
#   'Current Description': 'light rain'},
#  {'City': 'Smithers',
#   'Lat': 54.7804,
#   'Lng': -127.1743,
#   'Max Temp': 50.32,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Current Description': 'moderate rain'},
#  {'City': 'Imbituba',
#   'Lat': -28.24,
#   'Lng': -48.6703,
#   'Max Temp': 77.83,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 10.6,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Solone',
#   'Lat': 48.2081,
#   'Lng': 34.8721,
#   'Max Temp': 59.05,
#   'Humidity': 44,
#   'Cloudiness': 61,
#   'Wind Speed': 14.79,
#   'Country': 'UA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Astoria',
#   'Lat': 46.1879,
#   'Lng': -123.8313,
#   'Max Temp': 57.09,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 30.24,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 40.66,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'AR',
#   'Current Description': 'few clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 61.72,
#   'Humidity': 53,
#   'Cloudiness': 1,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Evensk',
#   'Lat': 61.95,
#   'Lng': 159.2333,
#   'Max Temp': 39.63,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 5.59,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 80.26,
#   'Humidity': 80,
#   'Cloudiness': 98,
#   'Wind Speed': 4.52,
#   'Country': 'PG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lashio',
#   'Lat': 22.9333,
#   'Lng': 97.75,
#   'Max Temp': 71.29,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 1.88,
#   'Country': 'MM',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 77.38,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 1.25,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Steamboat Springs',
#   'Lat': 40.485,
#   'Lng': -106.8317,
#   'Max Temp': 62.1,
#   'Humidity': 46,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Dicamay',
#   'Lat': 16.7561,
#   'Lng': 122.0037,
#   'Max Temp': 75.67,
#   'Humidity': 94,
#   'Cloudiness': 18,
#   'Wind Speed': 2.19,
#   'Country': 'PH',
#   'Current Description': 'few clouds'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 82.45,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.54,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kabalo',
#   'Lat': -6.05,
#   'Lng': 26.9167,
#   'Max Temp': 88.65,
#   'Humidity': 40,
#   'Cloudiness': 78,
#   'Wind Speed': 3.58,
#   'Country': 'CD',
#   'Current Description': 'broken clouds'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 83.08,
#   'Humidity': 77,
#   'Cloudiness': 65,
#   'Wind Speed': 20.47,
#   'Country': 'KI',
#   'Current Description': 'light rain'},
#  {'City': 'Arlit',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 98.92,
#   'Humidity': 6,
#   'Cloudiness': 0,
#   'Wind Speed': 4.92,
#   'Country': 'NE',
#   'Current Description': 'clear sky'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 36.77,
#   'Humidity': 83,
#   'Cloudiness': 52,
#   'Wind Speed': 22.5,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 77.09,
#   'Humidity': 73,
#   'Cloudiness': 11,
#   'Wind Speed': 14.88,
#   'Country': 'BR',
#   'Current Description': 'few clouds'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 39.7,
#   'Humidity': 51,
#   'Cloudiness': 2,
#   'Wind Speed': 5.37,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Cambridge',
#   'Lat': 43.3601,
#   'Lng': -80.3127,
#   'Max Temp': 64.98,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Lata',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 78.49,
#   'Humidity': 51,
#   'Cloudiness': 95,
#   'Wind Speed': 5.79,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 56.8,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 11.45,
#   'Country': 'JP',
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 78.39,
#   'Humidity': 78,
#   'Cloudiness': 39,
#   'Wind Speed': 13.31,
#   'Country': 'RE',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 73.27,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 3.62,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Colombia',
#   'Lat': 10.9878,
#   'Lng': -74.9547,
#   'Max Temp': 82.49,
#   'Humidity': 78,
#   'Cloudiness': 16,
#   'Wind Speed': 8.79,
#   'Country': 'CO',
#   'Current Description': 'few clouds'},
#  {'City': 'Matagami',
#   'Lat': 49.7502,
#   'Lng': -77.6328,
#   'Max Temp': 44.71,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lockhart',
#   'Lat': 28.6194,
#   'Lng': -81.4426,
#   'Max Temp': 75.16,
#   'Humidity': 80,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Hokitika',
#   'Lat': -42.7167,
#   'Lng': 170.9667,
#   'Max Temp': 42.93,
#   'Humidity': 73,
#   'Cloudiness': 5,
#   'Wind Speed': 3.62,
#   'Country': 'NZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Tete',
#   'Lat': -16.1564,
#   'Lng': 33.5867,
#   'Max Temp': 98.69,
#   'Humidity': 23,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'MZ',
#   'Current Description': 'scattered clouds'},
#  {'City': 'San Policarpo',
#   'Lat': 12.1791,
#   'Lng': 125.5072,
#   'Max Temp': 79.2,
#   'Humidity': 88,
#   'Cloudiness': 34,
#   'Wind Speed': 5.53,
#   'Country': 'PH',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 72.82,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'PT',
#   'Current Description': 'few clouds'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 60.06,
#   'Humidity': 91,
#   'Cloudiness': 61,
#   'Wind Speed': 2.33,
#   'Country': 'TL',
#   'Current Description': 'broken clouds'},
#  {'City': 'Cabedelo',
#   'Lat': -6.9811,
#   'Lng': -34.8339,
#   'Max Temp': 81.27,
#   'Humidity': 74,
#   'Cloudiness': 49,
#   'Wind Speed': 20.33,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 25.86,
#   'Humidity': 78,
#   'Cloudiness': 15,
#   'Wind Speed': 4.38,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 51.98,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Current Description': 'light intensity shower rain'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 62.92,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 65.26,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 5.91,
#   'Country': 'UY',
#   'Current Description': 'clear sky'},
#  {'City': 'Luanda',
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp': 82.4,
#   'Humidity': 57,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'AO',
#   'Current Description': 'few clouds'},
#  {'City': 'Snyder',
#   'Lat': 32.7179,
#   'Lng': -100.9176,
#   'Max Temp': 70.52,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Ilo',
#   'Lat': -17.6394,
#   'Lng': -71.3375,
#   'Max Temp': 58.06,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 28.42,
#   'Humidity': 92,
#   'Cloudiness': 71,
#   'Wind Speed': 13.04,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 28.8,
#   'Humidity': 81,
#   'Cloudiness': 15,
#   'Wind Speed': 8.9,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Bhikangaon',
#   'Lat': 21.8667,
#   'Lng': 75.95,
#   'Max Temp': 80.98,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.17,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 49.86,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 24.16,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Naustdal',
#   'Lat': 61.509,
#   'Lng': 5.7168,
#   'Max Temp': 71.56,
#   'Humidity': 49,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'NO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 25.79,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 18.9,
#   'Country': 'RU',
#   'Current Description': 'snow'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 70.74,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 27.63,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 56.88,
#   'Humidity': 63,
#   'Cloudiness': 10,
#   'Wind Speed': 6.69,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Bebedouro',
#   'Lat': -20.9494,
#   'Lng': -48.4792,
#   'Max Temp': 81.82,
#   'Humidity': 41,
#   'Cloudiness': 96,
#   'Wind Speed': 7.14,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 91.76,
#   'Humidity': 20,
#   'Cloudiness': 4,
#   'Wind Speed': 12.06,
#   'Country': 'MG',
#   'Current Description': 'clear sky'},
#  {'City': 'Mazagao',
#   'Lat': -0.115,
#   'Lng': -51.2894,
#   'Max Temp': 87.85,
#   'Humidity': 54,
#   'Cloudiness': 4,
#   'Wind Speed': 6.89,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Hengshui',
#   'Lat': 37.7322,
#   'Lng': 115.7011,
#   'Max Temp': 67.05,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.91,
#   'Country': 'CN',
#   'Current Description': 'light rain'},
#  {'City': 'Birjand',
#   'Lat': 32.8663,
#   'Lng': 59.2211,
#   'Max Temp': 90.07,
#   'Humidity': 6,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'IR',
#   'Current Description': 'clear sky'},
#  {'City': 'Vagur',
#   'Lat': 61.4732,
#   'Lng': -6.8119,
#   'Max Temp': 49.06,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 11.63,
#   'Country': 'FO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kampong Thum',
#   'Lat': 12.7111,
#   'Lng': 104.8887,
#   'Max Temp': 80.29,
#   'Humidity': 82,
#   'Cloudiness': 21,
#   'Wind Speed': 0.92,
#   'Country': 'KH',
#   'Current Description': 'few clouds'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 80.44,
#   'Humidity': 13,
#   'Cloudiness': 82,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 60.57,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'mist'},
#  {'City': 'Byron Bay',
#   'Lat': -28.65,
#   'Lng': 153.6167,
#   'Max Temp': 64.35,
#   'Humidity': 61,
#   'Cloudiness': 66,
#   'Wind Speed': 5.41,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Muisne',
#   'Lat': 0.6,
#   'Lng': -80.0333,
#   'Max Temp': 74.44,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 12.08,
#   'Country': 'EC',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 78.1,
#   'Humidity': 82,
#   'Cloudiness': 34,
#   'Wind Speed': 3.58,
#   'Country': 'IN',
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Hirado',
#   'Lat': 33.3597,
#   'Lng': 129.5531,
#   'Max Temp': 78.15,
#   'Humidity': 84,
#   'Cloudiness': 7,
#   'Wind Speed': 18.01,
#   'Country': 'JP',
#   'Current Description': 'clear sky'},
#  {'City': 'Soe',
#   'Lat': -9.8607,
#   'Lng': 124.284,
#   'Max Temp': 65.3,
#   'Humidity': 90,
#   'Cloudiness': 54,
#   'Wind Speed': 4.14,
#   'Country': 'ID',
#   'Current Description': 'broken clouds'},
#  {'City': 'Roald',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 72.52,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'NO',
#   'Current Description': 'clear sky'},
#  {'City': 'Torbat-E Jam',
#   'Lat': 35.244,
#   'Lng': 60.6225,
#   'Max Temp': 73.4,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 8.16,
#   'Country': 'IR',
#   'Current Description': 'clear sky'},
#  {'City': 'Kropotkin',
#   'Lat': 45.4375,
#   'Lng': 40.5756,
#   'Max Temp': 64.44,
#   'Humidity': 43,
#   'Cloudiness': 13,
#   'Wind Speed': 12.26,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Altay',
#   'Lat': 47.8667,
#   'Lng': 88.1167,
#   'Max Temp': 47.17,
#   'Humidity': 14,
#   'Cloudiness': 100,
#   'Wind Speed': 1.66,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 70.2,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'PT',
#   'Current Description': 'broken clouds'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 34.32,
#   'Humidity': 100,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Sabang',
#   'Lat': 5.8933,
#   'Lng': 95.3214,
#   'Max Temp': 82.58,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 13.27,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ruteng',
#   'Lat': -8.6136,
#   'Lng': 120.4721,
#   'Max Temp': 62.78,
#   'Humidity': 95,
#   'Cloudiness': 63,
#   'Wind Speed': 2.28,
#   'Country': 'ID',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nalut',
#   'Lat': 30.3333,
#   'Lng': 10.85,
#   'Max Temp': 92.34,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 5.35,
#   'Country': 'LY',
#   'Current Description': 'clear sky'},
#  {'City': 'San Jose',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 61.07,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 28.65,
#   'Humidity': 86,
#   'Cloudiness': 15,
#   'Wind Speed': 3.87,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Nuuk',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 32.61,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'GL',
#   'Current Description': 'clear sky'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 65.21,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 28.59,
#   'Country': 'NA',
#   'Current Description': 'clear sky'},
#  {'City': 'Hualmay',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 63,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 4.34,
#   'Country': 'PE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 49.91,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 64.72,
#   'Humidity': 72,
#   'Cloudiness': 98,
#   'Wind Speed': 13.8,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 49.82,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 13.27,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Silao',
#   'Lat': 20.9333,
#   'Lng': -101.4333,
#   'Max Temp': 59.38,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'MX',
#   'Current Description': 'broken clouds'},
#  {'City': 'Birao',
#   'Lat': 10.2849,
#   'Lng': 22.7882,
#   'Max Temp': 87.82,
#   'Humidity': 54,
#   'Cloudiness': 88,
#   'Wind Speed': 4.61,
#   'Country': 'CF',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 38.8,
#   'Humidity': 81,
#   'Cloudiness': 78,
#   'Wind Speed': 11.59,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Wanxian',
#   'Lat': 30.8039,
#   'Lng': 108.3897,
#   'Max Temp': 78.37,
#   'Humidity': 87,
#   'Cloudiness': 14,
#   'Wind Speed': 0.89,
#   'Country': 'CN',
#   'Current Description': 'light rain'},
#  {'City': 'Barkly West',
#   'Lat': -28.5354,
#   'Lng': 24.5215,
#   'Max Temp': 96.08,
#   'Humidity': 10,
#   'Cloudiness': 97,
#   'Wind Speed': 22.15,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kungurtug',
#   'Lat': 50.5994,
#   'Lng': 97.5228,
#   'Max Temp': 17.51,
#   'Humidity': 86,
#   'Cloudiness': 78,
#   'Wind Speed': 4.05,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Krasnoborsk',
#   'Lat': 61.5598,
#   'Lng': 45.934,
#   'Max Temp': 45.05,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 5.77,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jiuquan',
#   'Lat': 39.7432,
#   'Lng': 98.5174,
#   'Max Temp': 68.34,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 6.04,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 18.5,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.23,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Strezhevoy',
#   'Lat': 60.7333,
#   'Lng': 77.5889,
#   'Max Temp': 46.38,
#   'Humidity': 80,
#   'Cloudiness': 16,
#   'Wind Speed': 6.51,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Basoko',
#   'Lat': 1.2391,
#   'Lng': 23.616,
#   'Max Temp': 89.56,
#   'Humidity': 44,
#   'Cloudiness': 21,
#   'Wind Speed': 1.86,
#   'Country': 'CD',
#   'Current Description': 'few clouds'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 67.87,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 19.48,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Baghdad',
#   'Lat': 33.3406,
#   'Lng': 44.4009,
#   'Max Temp': 96.71,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'IQ',
#   'Current Description': 'clear sky'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 67.08,
#   'Humidity': 80,
#   'Cloudiness': 6,
#   'Wind Speed': 10.4,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Kaiserslautern',
#   'Lat': 49.45,
#   'Lng': 7.75,
#   'Max Temp': 73.35,
#   'Humidity': 32,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'DE',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dong Xoai',
#   'Lat': 11.5333,
#   'Lng': 106.9167,
#   'Max Temp': 76.14,
#   'Humidity': 92,
#   'Cloudiness': 25,
#   'Wind Speed': 3.51,
#   'Country': 'VN',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 80.71,
#   'Humidity': 62,
#   'Cloudiness': 92,
#   'Wind Speed': 8.3,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Havoysund',
#   'Lat': 70.9963,
#   'Lng': 24.6622,
#   'Max Temp': 65.28,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 7.78,
#   'Country': 'NO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ladario',
#   'Lat': -19.0047,
#   'Lng': -57.6017,
#   'Max Temp': 80.69,
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'BR',
#   'Current Description': 'smoke'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 66.09,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 1.14,
#   'Country': 'NU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ilhabela',
#   'Lat': -23.7781,
#   'Lng': -45.3581,
#   'Max Temp': 74.53,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 3.24,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Eirunepe',
#   'Lat': -6.6603,
#   'Lng': -69.8736,
#   'Max Temp': 85.01,
#   'Humidity': 58,
#   'Cloudiness': 14,
#   'Wind Speed': 1.57,
#   'Country': 'BR',
#   'Current Description': 'few clouds'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 59.41,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 78.98,
#   'Humidity': 75,
#   'Cloudiness': 15,
#   'Wind Speed': 18.95,
#   'Country': 'PF',
#   'Current Description': 'few clouds'},
#  {'City': 'Ponta Delgada',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 73.51,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 26.02,
#   'Humidity': 88,
#   'Cloudiness': 83,
#   'Wind Speed': 9.89,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kankon',
#   'Lat': 15.0167,
#   'Lng': 74.0167,
#   'Max Temp': 75.87,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.21,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 26.56,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 4.79,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Brigantine',
#   'Lat': 39.4101,
#   'Lng': -74.3646,
#   'Max Temp': 68.02,
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Rio Gallegos',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 41.05,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Benguela',
#   'Lat': -12.5763,
#   'Lng': 13.4055,
#   'Max Temp': 76.77,
#   'Humidity': 64,
#   'Cloudiness': 8,
#   'Wind Speed': 10.36,
#   'Country': 'AO',
#   'Current Description': 'clear sky'},
#  {'City': 'Bay Roberts',
#   'Lat': 47.5999,
#   'Lng': -53.2648,
#   'Max Temp': 62.06,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'CA',
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Temirtau',
#   'Lat': 50.0544,
#   'Lng': 72.9483,
#   'Max Temp': 44.85,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 11.3,
#   'Country': 'KZ',
#   'Current Description': 'light rain'},
#  {'City': 'Charlestown',
#   'Lat': -32.95,
#   'Lng': 151.6667,
#   'Max Temp': 59.74,
#   'Humidity': 76,
#   'Cloudiness': 46,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pemagatsel',
#   'Lat': 27.0319,
#   'Lng': 91.4266,
#   'Max Temp': 62.83,
#   'Humidity': 94,
#   'Cloudiness': 76,
#   'Wind Speed': 4.03,
#   'Country': 'BT',
#   'Current Description': 'broken clouds'},
#  {'City': 'Urusha',
#   'Lat': 54.05,
#   'Lng': 122.9,
#   'Max Temp': 39.87,
#   'Humidity': 82,
#   'Cloudiness': 97,
#   'Wind Speed': 5.82,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Polyarnyy',
#   'Lat': 69.1989,
#   'Lng': 33.4478,
#   'Max Temp': 55.87,
#   'Humidity': 75,
#   'Cloudiness': 60,
#   'Wind Speed': 8.63,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Aulnoye-Aymeries',
#   'Lat': 50.2014,
#   'Lng': 3.8384,
#   'Max Temp': 64.78,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 17.13,
#   'Country': 'FR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 34.11,
#   'Humidity': 85,
#   'Cloudiness': 14,
#   'Wind Speed': 0.6,
#   'Country': 'NZ',
#   'Current Description': 'few clouds'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 52.48,
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 7.74,
#   'Country': 'CL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Joseph',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 77.38,
#   'Humidity': 76,
#   'Cloudiness': 43,
#   'Wind Speed': 13.29,
#   'Country': 'RE',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 46.42,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'IS',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tessalit',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 101.14,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 4.99,
#   'Country': 'ML',
#   'Current Description': 'clear sky'},
#  {'City': 'Kyshtovka',
#   'Lat': 56.555,
#   'Lng': 76.6271,
#   'Max Temp': 40.96,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 7.45,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Orotukan',
#   'Lat': 62.2667,
#   'Lng': 151.7,
#   'Max Temp': 33.75,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Calama',
#   'Lat': -22.4667,
#   'Lng': -68.9333,
#   'Max Temp': 71.13,
#   'Humidity': 7,
#   'Cloudiness': 0,
#   'Wind Speed': 6.85,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 77.38,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'MU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Khor',
#   'Lat': 47.8861,
#   'Lng': 134.9464,
#   'Max Temp': 59.36,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 5.97,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rincon',
#   'Lat': 32.296,
#   'Lng': -81.2354,
#   'Max Temp': 66.85,
#   'Humidity': 94,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Abu Samrah',
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Max Temp': 91.02,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 19.24,
#   'Country': 'SY',
#   'Current Description': 'clear sky'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 59.25,
#   'Humidity': 91,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 54.37,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 14.63,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Turochak',
#   'Lat': 52.2576,
#   'Lng': 87.1224,
#   'Max Temp': 32.2,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 4.63,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 76.42,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'UZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Chernyshevskiy',
#   'Lat': 63.0128,
#   'Lng': 112.4714,
#   'Max Temp': 32.14,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 15.23,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lunenburg',
#   'Lat': 44.3835,
#   'Lng': -64.3155,
#   'Max Temp': 60.8,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 80.94,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 7.81,
#   'Country': 'IN',
#   'Current Description': 'light rain'},
#  {'City': 'Luziania',
#   'Lat': -16.2525,
#   'Lng': -47.9503,
#   'Max Temp': 79.99,
#   'Humidity': 30,
#   'Cloudiness': 6,
#   'Wind Speed': 7.45,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Bagua Grande',
#   'Lat': -5.7561,
#   'Lng': -78.4411,
#   'Max Temp': 78.57,
#   'Humidity': 63,
#   'Cloudiness': 19,
#   'Wind Speed': 1.34,
#   'Country': 'PE',
#   'Current Description': 'few clouds'},
#  {'City': 'Saint-Louis',
#   'Lat': 16.3333,
#   'Lng': -15,
#   'Max Temp': 98.24,
#   'Humidity': 30,
#   'Cloudiness': 93,
#   'Wind Speed': 2.04,
#   'Country': 'SN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Leh',
#   'Lat': 34.1667,
#   'Lng': 77.5833,
#   'Max Temp': 64.4,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 4.29,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Seddon',
#   'Lat': -37.8068,
#   'Lng': 144.8916,
#   'Max Temp': 55.98,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Tokmak',
#   'Lat': 47.2514,
#   'Lng': 35.7058,
#   'Max Temp': 63.54,
#   'Humidity': 36,
#   'Cloudiness': 17,
#   'Wind Speed': 11.14,
#   'Country': 'UA',
#   'Current Description': 'few clouds'},
#  {'City': 'Hondo',
#   'Lat': 32.45,
#   'Lng': 130.2,
#   'Max Temp': 78.75,
#   'Humidity': 76,
#   'Cloudiness': 86,
#   'Wind Speed': 7.47,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bonavista',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 58.12,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 22.15,
#   'Country': 'CA',
#   'Current Description': 'moderate rain'},
#  {'City': 'Prainha',
#   'Lat': -1.8,
#   'Lng': -53.48,
#   'Max Temp': 88.18,
#   'Humidity': 53,
#   'Cloudiness': 43,
#   'Wind Speed': 4.14,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saint-Jerome',
#   'Lat': 45.7804,
#   'Lng': -74.0036,
#   'Max Temp': 58.23,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Aleksandriya',
#   'Lat': 45.0947,
#   'Lng': 43.2456,
#   'Max Temp': 63.66,
#   'Humidity': 41,
#   'Cloudiness': 19,
#   'Wind Speed': 17.02,
#   'Country': 'RU',
#   'Current Description': 'few clouds'},
#  {'City': 'Bandundu',
#   'Lat': -3.3167,
#   'Lng': 17.3667,
#   'Max Temp': 88.59,
#   'Humidity': 48,
#   'Cloudiness': 98,
#   'Wind Speed': 6.64,
#   'Country': 'CD',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hobyo',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 81.39,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 29.46,
#   'Country': 'SO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Trenggalek',
#   'Lat': -8.05,
#   'Lng': 111.7167,
#   'Max Temp': 73.94,
#   'Humidity': 87,
#   'Cloudiness': 72,
#   'Wind Speed': 5.41,
#   'Country': 'ID',
#   'Current Description': 'broken clouds'},
#  {'City': 'Treinta Y Tres',
#   'Lat': -33.2333,
#   'Lng': -54.3833,
#   'Max Temp': 65.17,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 6.58,
#   'Country': 'UY',
#   'Current Description': 'clear sky'},
#  {'City': 'Mananjary',
#   'Lat': -21.2167,
#   'Lng': 48.3333,
#   'Max Temp': 74.77,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 8.12,
#   'Country': 'MG',
#   'Current Description': 'clear sky'},
#  {'City': 'Kidal',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 102.63,
#   'Humidity': 10,
#   'Cloudiness': 1,
#   'Wind Speed': 15.28,
#   'Country': 'ML',
#   'Current Description': 'clear sky'},
#  {'City': 'Tucumcari',
#   'Lat': 35.1717,
#   'Lng': -103.725,
#   'Max Temp': 62.44,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 61.97,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 16.2,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tocancipa',
#   'Lat': 4.9653,
#   'Lng': -73.913,
#   'Max Temp': 48.02,
#   'Humidity': 64,
#   'Cloudiness': 56,
#   'Wind Speed': 2.89,
#   'Country': 'CO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Killybegs',
#   'Lat': 54.6333,
#   'Lng': -8.45,
#   'Max Temp': 57.45,
#   'Humidity': 63,
#   'Cloudiness': 7,
#   'Wind Speed': 18.97,
#   'Country': 'IE',
#   'Current Description': 'clear sky'},
#  {'City': 'Gadwal',
#   'Lat': 16.2333,
#   'Lng': 77.8,
#   'Max Temp': 73.4,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 14.61,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 82.63,
#   'Humidity': 71,
#   'Cloudiness': 8,
#   'Wind Speed': 5.08,
#   'Country': 'TC',
#   'Current Description': 'clear sky'},
#  {'City': 'Hay River',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': 44.58,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Shemursha',
#   'Lat': 54.8866,
#   'Lng': 47.5189,
#   'Max Temp': 40.3,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 14.79,
#   'Country': 'RU',
# ...
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'VG',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Shubarkuduk',
#   'Lat': 49.1447,
#   'Lng': 56.4872,
#   'Max Temp': 56.75,
#   'Humidity': 51,
#   'Cloudiness': 66,
#   'Wind Speed': 15.73,
#   'Country': 'KZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Lambarene',
#   'Lat': -0.7001,
#   'Lng': 10.2406,
#   'Max Temp': 86.02,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 3.78,
#   'Country': 'GA',
#   'Current Description': 'light rain'},
#  {'City': 'Nanyuki',
#   'Lat': 0.0167,
#   'Lng': 37.0728,
#   'Max Temp': 69.76,
#   'Humidity': 49,
#   'Cloudiness': 97,
#   'Wind Speed': 5.77,
#   'Country': 'KE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zhezkazgan',
#   'Lat': 47.8043,
#   'Lng': 67.7144,
#   'Max Temp': 64.45,
#   'Humidity': 35,
#   'Cloudiness': 78,
#   'Wind Speed': 22.15,
#   'Country': 'KZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Toamasina',
#   'Lat': -18.1667,
#   'Lng': 49.3833,
#   'Max Temp': 78.8,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'MG',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 76.23,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Karachi',
#   'Lat': 24.9056,
#   'Lng': 67.0822,
#   'Max Temp': 85.82,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'PK',
#   'Current Description': 'very heavy rain'},
#  {'City': 'Nunchia',
#   'Lat': 5.6406,
#   'Lng': -72.1986,
#   'Max Temp': 78.15,
#   'Humidity': 74,
#   'Cloudiness': 80,
#   'Wind Speed': 1.01,
#   'Country': 'CO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pakxe',
#   'Lat': 15.1167,
#   'Lng': 105.7833,
#   'Max Temp': 84.34,
#   'Humidity': 84,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Country': 'LA',
#   'Current Description': 'thunderstorm'},
#  {'City': 'Languyan',
#   'Lat': 5.2618,
#   'Lng': 120.0807,
#   'Max Temp': 80.76,
#   'Humidity': 81,
#   'Cloudiness': 34,
#   'Wind Speed': 3.65,
#   'Country': 'PH',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Culiacancito',
#   'Lat': 24.8247,
#   'Lng': -107.5331,
#   'Max Temp': 77.95,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 4,
#   'Country': 'MX',
#   'Current Description': 'few clouds'},
#  {'City': 'Waipawa',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 47.03,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 10.04,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 36.52,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 7.52,
#   'Country': 'GL',
#   'Current Description': 'clear sky'},
#  {'City': 'Dali',
#   'Lat': 25.7,
#   'Lng': 100.1833,
#   'Max Temp': 64.13,
#   'Humidity': 78,
#   'Cloudiness': 37,
#   'Wind Speed': 4.74,
#   'Country': 'CN',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kholm-Zhirkovskiy',
#   'Lat': 55.5189,
#   'Lng': 33.4731,
#   'Max Temp': 50.49,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 8.88,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Urumqi',
#   'Lat': 43.801,
#   'Lng': 87.6005,
#   'Max Temp': 65.35,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Riyadh',
#   'Lat': 24.6877,
#   'Lng': 46.7219,
#   'Max Temp': 96.94,
#   'Humidity': 6,
#   'Cloudiness': 100,
#   'Wind Speed': 19.91,
#   'Country': 'SA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Stornoway',
#   'Lat': 58.2093,
#   'Lng': -6.3865,
#   'Max Temp': 53.56,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'GB',
#   'Current Description': 'light intensity shower rain'},
#  {'City': 'Kendari',
#   'Lat': -3.945,
#   'Lng': 122.4989,
#   'Max Temp': 76.95,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.78,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kimbe',
#   'Lat': -5.5502,
#   'Lng': 150.1429,
#   'Max Temp': 75.92,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.25,
#   'Country': 'PG',
#   'Current Description': 'moderate rain'},
#  {'City': 'Ulu-Telyak',
#   'Lat': 54.9086,
#   'Lng': 56.9669,
#   'Max Temp': 39.11,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 12.59,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Sawtell',
#   'Lat': -30.3833,
#   'Lng': 153.1,
#   'Max Temp': 59.02,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Terrace Bay',
#   'Lat': 48.7834,
#   'Lng': -87.1,
#   'Max Temp': 41.5,
#   'Humidity': 81,
#   'Cloudiness': 92,
#   'Wind Speed': 11.23,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Moron',
#   'Lat': -34.6534,
#   'Lng': -58.6198,
#   'Max Temp': 60.49,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Country': 'AR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kenai',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 34.14,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Yerbogachen',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': 35.67,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 13.44,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Knysna',
#   'Lat': -34.0363,
#   'Lng': 23.0471,
#   'Max Temp': 62.98,
#   'Humidity': 79,
#   'Cloudiness': 85,
#   'Wind Speed': 10.27,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bowen',
#   'Lat': -20.0167,
#   'Lng': 148.2333,
#   'Max Temp': 71.82,
#   'Humidity': 77,
#   'Cloudiness': 5,
#   'Wind Speed': 17.81,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Lucea',
#   'Lat': 18.451,
#   'Lng': -78.1736,
#   'Max Temp': 84.06,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 7.31,
#   'Country': 'JM',
#   'Current Description': 'clear sky'},
#  {'City': 'Alyangula',
#   'Lat': -13.8483,
#   'Lng': 136.4192,
#   'Max Temp': 76.87,
#   'Humidity': 88,
#   'Cloudiness': 81,
#   'Wind Speed': 2.3,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kollam',
#   'Lat': 8.8833,
#   'Lng': 76.6,
#   'Max Temp': 80.47,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 13.94,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Andenes',
#   'Lat': 69.3143,
#   'Lng': 16.1194,
#   'Max Temp': 62.47,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'NO',
#   'Current Description': 'clear sky'},
#  {'City': 'Bud',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 65.89,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 12.95,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Tilichiki',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp': 34.99,
#   'Humidity': 88,
#   'Cloudiness': 77,
#   'Wind Speed': 5.35,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kautokeino',
#   'Lat': 69.0125,
#   'Lng': 23.0412,
#   'Max Temp': 55.67,
#   'Humidity': 77,
#   'Cloudiness': 35,
#   'Wind Speed': 14.54,
#   'Country': 'NO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bom Jesus Da Lapa',
#   'Lat': -13.255,
#   'Lng': -43.4181,
#   'Max Temp': 88.09,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Sinop',
#   'Lat': 41.7711,
#   'Lng': 34.8709,
#   'Max Temp': 63.03,
#   'Humidity': 62,
#   'Cloudiness': 18,
#   'Wind Speed': 7.7,
#   'Country': 'TR',
#   'Current Description': 'few clouds'},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 91.36,
#   'Humidity': 12,
#   'Cloudiness': 2,
#   'Wind Speed': 6.04,
#   'Country': 'YE',
#   'Current Description': 'clear sky'},
#  {'City': 'Thap Than',
#   'Lat': 15.4606,
#   'Lng': 99.8917,
#   'Max Temp': 77.49,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 3.29,
#   'Country': 'TH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lac-Au-Saumon',
#   'Lat': 48.421,
#   'Lng': -67.3476,
#   'Max Temp': 52.81,
#   'Humidity': 85,
#   'Cloudiness': 7,
#   'Wind Speed': 9.51,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 28.9,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 4.92,
#   'Country': 'GL',
#   'Current Description': 'clear sky'},
#  {'City': 'Kampot',
#   'Lat': 10.6167,
#   'Lng': 104.1833,
#   'Max Temp': 82.45,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.38,
#   'Country': 'KH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tokur',
#   'Lat': 53.1333,
#   'Lng': 132.9,
#   'Max Temp': 46.53,
#   'Humidity': 96,
#   'Cloudiness': 89,
#   'Wind Speed': 5.53,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Makat',
#   'Lat': 47.6469,
#   'Lng': 53.3463,
#   'Max Temp': 62.42,
#   'Humidity': 37,
#   'Cloudiness': 100,
#   'Wind Speed': 21.9,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 58.37,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 8.57,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pontarlier',
#   'Lat': 46.8333,
#   'Lng': 6.25,
#   'Max Temp': 66.16,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 7.18,
#   'Country': 'FR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 28.4,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hinganghat',
#   'Lat': 20.5667,
#   'Lng': 78.8333,
#   'Max Temp': 85.41,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 13.87,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hammerfest',
#   'Lat': 70.6634,
#   'Lng': 23.6821,
#   'Max Temp': 64.85,
#   'Humidity': 59,
#   'Cloudiness': 40,
#   'Wind Speed': 1.14,
#   'Country': 'NO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sibolga',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 77.14,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.75,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Oktyabrskiy',
#   'Lat': 54.4815,
#   'Lng': 53.471,
#   'Max Temp': 45.61,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 18.39,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Voronezh',
#   'Lat': 51.6664,
#   'Lng': 39.17,
#   'Max Temp': 53.62,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Abha',
#   'Lat': 18.2164,
#   'Lng': 42.5053,
#   'Max Temp': 82.22,
#   'Humidity': 13,
#   'Cloudiness': 20,
#   'Wind Speed': 18.41,
#   'Country': 'SA',
#   'Current Description': 'few clouds'},
#  {'City': 'Kolosovka',
#   'Lat': 56.4678,
#   'Lng': 73.611,
#   'Max Temp': 40.12,
#   'Humidity': 72,
#   'Cloudiness': 95,
#   'Wind Speed': 10,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gambela',
#   'Lat': 8.25,
#   'Lng': 34.5833,
#   'Max Temp': 86.23,
#   'Humidity': 54,
#   'Cloudiness': 19,
#   'Wind Speed': 2.89,
#   'Country': 'ET',
#   'Current Description': 'few clouds'},
#  {'City': 'Amazar',
#   'Lat': 53.858,
#   'Lng': 120.875,
#   'Max Temp': 42.8,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 9.13,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Talara',
#   'Lat': -4.5772,
#   'Lng': -81.2719,
#   'Max Temp': 61.56,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'PE',
#   'Current Description': 'clear sky'},
#  {'City': 'Male',
#   'Lat': 4.1748,
#   'Lng': 73.5089,
#   'Max Temp': 80.55,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 19.57,
#   'Country': 'MV',
#   'Current Description': 'very heavy rain'},
#  {'City': 'Pochutla',
#   'Lat': 15.7432,
#   'Lng': -96.4661,
#   'Max Temp': 74.01,
#   'Humidity': 80,
#   'Cloudiness': 36,
#   'Wind Speed': 4.21,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Catamarca',
#   'Lat': -28.4696,
#   'Lng': -65.7852,
#   'Max Temp': 73.04,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Adet',
#   'Lat': 11.2644,
#   'Lng': 37.4888,
#   'Max Temp': 68.86,
#   'Humidity': 58,
#   'Cloudiness': 92,
#   'Wind Speed': 4.61,
#   'Country': 'ET',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Leek',
#   'Lat': 53.1625,
#   'Lng': 6.3764,
#   'Max Temp': 69.98,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'NL',
#   'Current Description': 'broken clouds'},
#  {'City': 'Marshfield',
#   'Lat': 44.6689,
#   'Lng': -90.1718,
#   'Max Temp': 55.38,
#   'Humidity': 94,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 49.89,
#   'Humidity': 73,
#   'Cloudiness': 28,
#   'Wind Speed': 7.18,
#   'Country': 'NZ',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lyuban',
#   'Lat': 52.7985,
#   'Lng': 28.0048,
#   'Max Temp': 53.02,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'BY',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Severobaykalsk',
#   'Lat': 55.65,
#   'Lng': 109.3167,
#   'Max Temp': 35.4,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 7.52,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Robinson',
#   'Lat': 31.4677,
#   'Lng': -97.1147,
#   'Max Temp': 65.88,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Zharkent',
#   'Lat': 44.1628,
#   'Lng': 80,
#   'Max Temp': 74.35,
#   'Humidity': 20,
#   'Cloudiness': 65,
#   'Wind Speed': 19.19,
#   'Country': 'KZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Abnub',
#   'Lat': 27.2696,
#   'Lng': 31.1511,
#   'Max Temp': 89.82,
#   'Humidity': 22,
#   'Cloudiness': 21,
#   'Wind Speed': 14.79,
#   'Country': 'EG',
#   'Current Description': 'few clouds'},
#  {'City': 'Chunoyar',
#   'Lat': 57.4467,
#   'Lng': 97.3217,
#   'Max Temp': 35.01,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mao',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 79.36,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'ES',
#   'Current Description': 'few clouds'},
#  {'City': 'Dubbo',
#   'Lat': -32.25,
#   'Lng': 148.6167,
#   'Max Temp': 57.33,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Piedras Negras',
#   'Lat': 28.7,
#   'Lng': -100.5167,
#   'Max Temp': 70.27,
#   'Humidity': 75,
#   'Cloudiness': 95,
#   'Wind Speed': 5.91,
#   'Country': 'MX',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Svetlyy',
#   'Lat': 54.675,
#   'Lng': 20.1347,
#   'Max Temp': 60.85,
#   'Humidity': 46,
#   'Cloudiness': 30,
#   'Wind Speed': 13.91,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kristiinankaupunki',
#   'Lat': 62.2743,
#   'Lng': 21.376,
#   'Max Temp': 55.45,
#   'Humidity': 61,
#   'Cloudiness': 35,
#   'Wind Speed': 8.63,
#   'Country': 'FI',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Raymondville',
#   'Lat': 26.4815,
#   'Lng': -97.7831,
#   'Max Temp': 75.9,
#   'Humidity': 86,
#   'Cloudiness': 58,
#   'Wind Speed': 4.72,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ilheus',
#   'Lat': -14.7889,
#   'Lng': -39.0494,
#   'Max Temp': 82.22,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kailua',
#   'Lat': 21.4022,
#   'Lng': -157.7394,
#   'Max Temp': 78.78,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'San Rafael Del Sur',
#   'Lat': 11.8485,
#   'Lng': -86.4384,
#   'Max Temp': 76.17,
#   'Humidity': 81,
#   'Cloudiness': 51,
#   'Wind Speed': 8.52,
#   'Country': 'NI',
#   'Current Description': 'broken clouds'}]

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Vaini -21.2000 -175.2000     60.96       100          20        3.44
# 1    Tuatapere -46.1333  167.6833     38.82        85          94        5.48
# 2    Cape Town -33.9258   18.4232     64.11        73          75       14.97
# 3  New Norfolk -42.7826  147.0587     49.71        94          20        2.75
# 4        Kapaa  22.0752 -159.3190     75.52        84          75        1.01
# 5       Dingle  10.9995  122.6711     76.80        92          99        2.98
# 6      Kodinsk  58.6881   99.1844     34.50        98         100        5.91
# 7        Tiksi  71.6872  128.8694     33.93        97         100       12.12
# 8    Busselton -33.6500  115.3333     56.05        90           6        9.84
# 9   Georgetown   5.4112  100.3354     84.88        78          20        1.01
#
#   Country Current Description
# 0      TO          few clouds
# 1      NZ     overcast clouds
# 2      ZA       broken clouds
# 3      AU          few clouds
# 4      US       moderate rain
# 5      PH     overcast clouds
# 6      RU     overcast clouds
# 7      RU     overcast clouds
# 8      AU           clear sky
# 9      MY          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Vaini      TO -21.2000 -175.2000     60.96       100          20
# 1    Tuatapere      NZ -46.1333  167.6833     38.82        85          94
# 2    Cape Town      ZA -33.9258   18.4232     64.11        73          75
# 3  New Norfolk      AU -42.7826  147.0587     49.71        94          20
# 4        Kapaa      US  22.0752 -159.3190     75.52        84          75
# 5       Dingle      PH  10.9995  122.6711     76.80        92          99
# 6      Kodinsk      RU  58.6881   99.1844     34.50        98         100
# 7        Tiksi      RU  71.6872  128.8694     33.93        97         100
# 8    Busselton      AU -33.6500  115.3333     56.05        90           6
# 9   Georgetown      MY   5.4112  100.3354     84.88        78          20
#
#    Wind Speed Current Description
# 0        3.44          few clouds
# 1        5.48     overcast clouds
# 2       14.97       broken clouds
# 3        2.75          few clouds
# 4        1.01       moderate rain
# 5        2.98     overcast clouds
# 6        5.91     overcast clouds
# 7       12.12     overcast clouds
# 8        9.84           clear sky
# 9        1.01          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
